# %%
import pandas as pd
from textblob import TextBlob

# %%
bike_survey_london= pd.read_csv("assembly-bike-survey-data_london.csv")
bike_survey_london.head(5)
# Out:
#    RespondentID Q1-Location Q2-Age Q3-Gender Q4-BikeOwner  \
# 0    1203127707        Kent  30-39      Male          Yes
# 1    1202170092      Camden  40-49      Male           No
# 2    1200588266    Richmond  18-29      Male          Yes
# 3    1200133603         NaN  40-49      Male           No
# 4    1199557604      Sutton  30-39      Male          Yes
#
#                        Q5-StartedCycling Q6-WhenStarted  \
# 0                   No, I already cycled         1 year
# 1  Yes, because of the Cycle Hire Scheme            NaN
# 2                   No, I already cycled         Longer
# 3  Yes, because of the Cycle Hire Scheme         Longer
# 4                   No, I already cycled         Longer
#
#                              Q8-SuperhighwayUsed Q9-SuperhighwayFrequency  \
# 0  Superhighway 7, Merton to the City via A24-A3       Only tried it once
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3  Superhighway 7, Merton to the City via A24-A3              Once a week
# 4  Superhighway 7, Merton to the City via A24-A3             Occasionally
#
#    Q10-Width  ...         Q19-Frequency                  Q20-Reason  \
# 0       fair  ...      Once a fortnight  A combination of the above
# 1        NaN  ...  Several times a week  A combination of the above
# 2        NaN  ...      Once a fortnight  A combination of the above
# 3       good  ...  Several times a week  A combination of the above
# 4  very good  ...  Several times a week  A combination of the above
#
#                    Q20-ReasonOther       Q21-Duration Q22-SupportCentre  \
# 0    Tube, walking, bus and train.  Less than 30 mins                No
# 1                              NaN  Less than 30 mins                No
# 2         Instead of tube/walk/bus  Less than 30 mins                No
# 3     Bus, tube, train and walking  Less than 30 mins               Yes
# 4  Instead of walking, bus or tube  Less than 30 mins                No
#
#                                          Q23-Problem Q24-SupportExperience  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2                                                NaN                   NaN
# 3  The wrong fob key was sent out.  It did not co...             Very good
# 4                                                NaN                   NaN
#
#                                  Q25-SupportComments  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  General comments:  I love the scheme.  Please ...
# 4                                                NaN
#
#                                     Q26-Improvements Q27-Reason
# 0  There should be the provision to be able to hi...        NaN
# 1  The docking point opposite the Black Cats fact...        NaN
# 2                                                NaN        NaN
# 3  The bikes could have more reflectors on them. ...        NaN
# 4  Just need many more stations to be left as spa...        NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Sentimental analyst using text blob and polarity

# %%
# Drop rows with missing values in the text column
bike_survey_london= bike_survey_london.dropna(subset=['Q25-SupportComments'])

# %%
# Create a function to get the sentiment polarity using TextBlob
def get_sentiment(text):
    analysis = TextBlob(str(text))
    return analysis.sentiment.polarity

# Apply the function to your text column
bike_survey_london['Sentiment_Polarity'] = bike_survey_london['Q25-SupportComments'].apply(get_sentiment)
bike_survey_london['Sentiment_Polarity']
# Out:
# 3       0.293750
# 7       0.100000
# 12      0.700000
# 13      0.116667
# 30      0.433333
#           ...
# 1282   -0.077778
# 1284    0.083333
# 1285   -0.050000
# 1288    0.073611
# 1291   -0.095000
# Name: Sentiment_Polarity, Length: 314, dtype: float64

# %%
bike_survey_london['Sentiment_Category'] = pd.cut(bike_survey_london['Sentiment_Polarity'], bins=3, labels=['Negative', 'Neutral', 'Positive'])
bike_survey_london.head()
# Out:
#     RespondentID           Q1-Location Q2-Age Q3-Gender Q4-BikeOwner  \
# 3     1200133603                   NaN  40-49      Male           No
# 7     1198050062                Merton  40-49      Male          Yes
# 12    1197323125  Richmond upon Thames  40-49      Male          Yes
# 13    1196772000                Camden  40-49      Male          Yes
# 30    1195777047         tower hamlets  18-29      Male          Yes
#
#                         Q5-StartedCycling Q6-WhenStarted  \
# 3   Yes, because of the Cycle Hire Scheme         Longer
# 7                    No, I already cycled         Longer
# 12                   No, I already cycled         Longer
# 13                   No, I already cycled         Longer
# 30                   No, I already cycled         Longer
#
#                               Q8-SuperhighwayUsed Q9-SuperhighwayFrequency  \
# 3   Superhighway 7, Merton to the City via A24-A3              Once a week
# 7   Superhighway 7, Merton to the City via A24-A3       Only tried it once
# 12                                            NaN                      NaN
# 13                                            NaN                      NaN
# 30                                            NaN                      NaN
#
#    Q10-Width  ...                                    Q20-ReasonOther  \
# 3       good  ...                       Bus, tube, train and walking
# 7       good  ...                                                NaN
# 12       NaN  ...                              Tube, taxis, walking.
# 13       NaN  ...               bus, tube, walk, train. Combination!
# 30       NaN  ...  instead of tube/bus, instead of walking, inste...
#
#          Q21-Duration Q22-SupportCentre  \
# 3   Less than 30 mins               Yes
# 7   Less than 30 mins               Yes
# 12  Less than 30 mins               Yes
# 13  Less than 30 mins               Yes
# 30  Less than 30 mins               Yes
#
#                                           Q23-Problem Q24-SupportExperience  \
# 3   The wrong fob key was sent out.  It did not co...             Very good
# 7   Was incorrectly billed for several hours of bi...                  Poor
# 12  Billing mostly. I'm one of the people affected...                  Good
# 13  Bike wouldn't release at the station I was using.             Very poor
# 30  auto top up had not been activated once, the s...             Very good
#
#                                   Q25-SupportComments  \
# 3   General comments:  I love the scheme.  Please ...
# 7   I was told that the incorrect fee would be tak...
# 12  Support has been good. The shame is that I hav...
# 13  Had to queue for literally over an hour. Assis...
# 30  very quick to talk to me, very quick to sort o...
#
#                                      Q26-Improvements Q27-Reason  \
# 3   The bikes could have more reflectors on them. ...        NaN
# 7                                                 NaN        NaN
# 12  I want to be able to have more than one key on...        NaN
# 13  Distribution, distribution, distribution! Also...        NaN
# 30  the cycle map on the barclays bikes website's ...        NaN
#
#    Sentiment_Polarity Sentiment_Category
# 3            0.293750            Neutral
# 7            0.100000            Neutral
# 12           0.700000           Positive
# 13           0.116667            Neutral
# 30           0.433333           Positive
#
# [5 rows x 40 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each sentiment category
sentiment_counts = bike_survey_london['Sentiment_Category'].value_counts()

# Plot the distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values)
plt.title('Sentiment Distribution Bike survey London')
plt.xlabel('Sentiment Category')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Sentiment analysis using VADER (Valence Aware Dictionary and Sentiment Reasoner)

# %%
#pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
bike_survey_london= pd.read_csv("assembly-bike-survey-data_london.csv")

# %%
# Drop rows with missing values in the text column
bike_survey_london= bike_survey_london.dropna(subset=['Q25-SupportComments'])
bike_survey_london["Q25-SupportComments"].head(10)
# Out:
# 3     General comments:  I love the scheme.  Please ...
# 7     I was told that the incorrect fee would be tak...
# 12    Support has been good. The shame is that I hav...
# 13    Had to queue for literally over an hour. Assis...
# 30    very quick to talk to me, very quick to sort o...
# 36    Call centre was busy, they took my name and nu...
# 41    I needed 3 separate calls to resolve my regist...
# 57             I have never been able to get a response
# 60    Nice people but unable to solve any real problems
# 61    Quite a delay, then not answered by someone wi...
# Name: Q25-SupportComments, dtype: object

# %%
# Create a function to get the compound sentiment score using VADER
def get_vader_sentiment(text):
    analyzer = SentimentIntensityAnalyzer()
    compound_score = analyzer.polarity_scores(str(text))['compound']
    return compound_score

# Apply the function to your text column
bike_survey_london['VADER_Sentiment_Score'] = bike_survey_london['Q25-SupportComments'].apply(get_vader_sentiment)
bike_survey_london.head()
# Out:
#     RespondentID           Q1-Location Q2-Age Q3-Gender Q4-BikeOwner  \
# 3     1200133603                   NaN  40-49      Male           No
# 7     1198050062                Merton  40-49      Male          Yes
# 12    1197323125  Richmond upon Thames  40-49      Male          Yes
# 13    1196772000                Camden  40-49      Male          Yes
# 30    1195777047         tower hamlets  18-29      Male          Yes
#
#                         Q5-StartedCycling Q6-WhenStarted  \
# 3   Yes, because of the Cycle Hire Scheme         Longer
# 7                    No, I already cycled         Longer
# 12                   No, I already cycled         Longer
# 13                   No, I already cycled         Longer
# 30                   No, I already cycled         Longer
#
#                               Q8-SuperhighwayUsed Q9-SuperhighwayFrequency  \
# 3   Superhighway 7, Merton to the City via A24-A3              Once a week
# 7   Superhighway 7, Merton to the City via A24-A3       Only tried it once
# 12                                            NaN                      NaN
# 13                                            NaN                      NaN
# 30                                            NaN                      NaN
#
#    Q10-Width  ...                  Q20-Reason  \
# 3       good  ...  A combination of the above
# 7       good  ...  Instead of taking the Tube
# 12       NaN  ...  A combination of the above
# 13       NaN  ...  A combination of the above
# 30       NaN  ...  A combination of the above
#
#                                       Q20-ReasonOther       Q21-Duration  \
# 3                        Bus, tube, train and walking  Less than 30 mins
# 7                                                 NaN  Less than 30 mins
# 12                              Tube, taxis, walking.  Less than 30 mins
# 13               bus, tube, walk, train. Combination!  Less than 30 mins
# 30  instead of tube/bus, instead of walking, inste...  Less than 30 mins
#
#    Q22-SupportCentre                                        Q23-Problem  \
# 3                Yes  The wrong fob key was sent out.  It did not co...
# 7                Yes  Was incorrectly billed for several hours of bi...
# 12               Yes  Billing mostly. I'm one of the people affected...
# 13               Yes  Bike wouldn't release at the station I was using.
# 30               Yes  auto top up had not been activated once, the s...
#
#    Q24-SupportExperience                                Q25-SupportComments  \
# 3              Very good  General comments:  I love the scheme.  Please ...
# 7                   Poor  I was told that the incorrect fee would be tak...
# 12                  Good  Support has been good. The shame is that I hav...
# 13             Very poor  Had to queue for literally over an hour. Assis...
# 30             Very good  very quick to talk to me, very quick to sort o...
#
#                                      Q26-Improvements Q27-Reason  \
# 3   The bikes could have more reflectors on them. ...        NaN
# 7                                                 NaN        NaN
# 12  I want to be able to have more than one key on...        NaN
# 13  Distribution, distribution, distribution! Also...        NaN
# 30  the cycle map on the barclays bikes website's ...        NaN
#
#    VADER_Sentiment_Score
# 3                 0.8984
# 7                 0.0000
# 12                0.3612
# 13               -0.5789
# 30               -0.1134
#
# [5 rows x 39 columns]

# %%
# Create categories based on the VADER compound score
bike_survey_london['Sentiment_Category_VADER'] = pd.cut(bike_survey_london['VADER_Sentiment_Score'], bins=3, labels=['Negative', 'Neutral', 'Positive'])

# %%
# Assuming df is your DataFrame with the VADER sentiment scores
bike_survey_london = bike_survey_london.dropna(subset=['Q25-SupportComments', 'VADER_Sentiment_Score'])

# Plotting
plt.figure(figsize=(10, 6))
sns.histplot(bike_survey_london['VADER_Sentiment_Score'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of VADER Sentiment Scores')
plt.xlabel('VADER Sentiment Score (Compound)')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame with sentiment categories
bike_survey_london = bike_survey_london.dropna(subset=['Sentiment_Category_VADER'])

# Count the occurrences of each sentiment category
sentiment_counts = bike_survey_london['Sentiment_Category_VADER'].value_counts()

# Plot the distribution
plt.figure(figsize=(8, 5))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values, palette='viridis')
plt.title('Sentiment Distribution Bike survey London')
plt.xlabel('Sentiment Category')
plt.ylabel('Count')
plt.show()
